# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import GridSearchCV

# %%
train = pd.read_csv('SalaryData_Train(1).csv')
train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# 2       Handlers-cleaners   Not-in-family   White     Male            0
# 3       Handlers-cleaners         Husband   Black     Male            0
# 4          Prof-specialty            Wife   Black   Female            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            13   United-States   <=50K
# 2                0            40   United-States   <=50K
# 3                0            40   United-States   <=50K
# 4                0            40            Cuba   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [30161 rows x 14 columns]

# %%
test = pd.read_csv('SalaryData_Test(1).csv')
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
train.corr()
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.043525     0.080152     0.060278      0.101598
# educationno   0.043525     1.000000     0.124416     0.079691      0.152522
# capitalgain   0.080152     0.124416     1.000000    -0.032218      0.080431
# capitalloss   0.060278     0.079691    -0.032218     1.000000      0.052454
# hoursperweek  0.101598     0.152522     0.080431     0.052454      1.000000

# %%
test.corr()
# Out:
#                    age  educationno  capitalgain  capitalloss  hoursperweek
# age           1.000000     0.026123     0.078760     0.057745      0.102758
# educationno   0.026123     1.000000     0.131750     0.085817      0.133691
# capitalgain   0.078760     0.131750     1.000000    -0.031876      0.090501
# capitalloss   0.057745     0.085817    -0.031876     1.000000      0.057712
# hoursperweek  0.102758     0.133691     0.090501     0.057712      1.000000

# %%
lb = LabelEncoder()

# %%
train["workclass"] = lb.fit_transform(train["workclass"])
train["education"] = lb.fit_transform(train["education"])
train["maritalstatus"] = lb.fit_transform(train["maritalstatus"])
train["occupation"] = lb.fit_transform(train["occupation"])
train["relationship"] = lb.fit_transform(train["relationship"])
train["race"] = lb.fit_transform(train["race"])
train["sex"] = lb.fit_transform(train["sex"])
train["native"] = lb.fit_transform(train["native"])
train["Salary"] = lb.fit_transform(train["Salary"])

# %%
test["workclass"] = lb.fit_transform(test["workclass"])
test["education"] = lb.fit_transform(test["education"])
test["maritalstatus"] = lb.fit_transform(test["maritalstatus"])
test["occupation"] = lb.fit_transform(test["occupation"])
test["relationship"] = lb.fit_transform(test["relationship"])
test["race"] = lb.fit_transform(test["race"])
test["sex"] = lb.fit_transform(test["sex"])
test["native"] = lb.fit_transform(test["native"])
test["Salary"] = lb.fit_transform(test["Salary"])

# %%
train = train.iloc[: 2000, :]

# %%
test = test.iloc[: 1300, :]

# %%
train.corr()
# Out:
#                     age  workclass  education  educationno  maritalstatus  \
# age            1.000000   0.080136  -0.004007     0.014781      -0.249467
# workclass      0.080136   1.000000   0.029167     0.068866      -0.043219
# education     -0.004007   0.029167   1.000000     0.328746      -0.047668
# educationno    0.014781   0.068866   0.328746     1.000000      -0.062303
# relationship  -0.253358  -0.082095  -0.024427    -0.050679       0.197796
# race           0.003103   0.065081  -0.005501     0.072135      -0.085572
# sex            0.074865   0.049687  -0.011597    -0.011529      -0.147099
# capitalgain    0.107361   0.053677   0.060160     0.170971      -0.071843
# capitalloss    0.057418   0.062026   0.038734     0.111713      -0.018926
# hoursperweek   0.106105   0.077106   0.063598     0.145317      -0.161722
# native         0.018697   0.043338   0.069760     0.106144       0.005488
# Salary         0.226220   0.077615   0.119016     0.313422      -0.226209
#
#                occupation  relationship      race       sex  capitalgain  \
# age             -0.035747     -0.253358  0.003103  0.074865     0.107361
# workclass        0.011914     -0.082095  0.065081  0.049687     0.053677
# education       -0.023030     -0.024427 -0.005501 -0.011597     0.060160
# educationno      0.077972     -0.050679  0.072135 -0.011529     0.170971
# maritalstatus   -0.012545      0.197796 -0.085572 -0.147099    -0.071843
# occupation       1.000000     -0.063657  0.037160  0.073262     0.004247
# relationship    -0.063657      1.000000 -0.158517 -0.588370    -0.060524
# race             0.037160     -0.158517  1.000000  0.072954     0.017319
# sex              0.073262     -0.588370  0.072954  1.000000     0.070784
# capitalgain      0.004247     -0.060524  0.017319  0.070784     1.000000
# capitalloss     -0.038230     -0.037262  0.064287  0.053486    -0.036077
# hoursperweek     0.018785     -0.298815  0.058017  0.233998     0.128418
# native           0.004193      0.015321  0.160356 -0.037813     0.032191
# Salary           0.018910     -0.259728  0.076017  0.206553     0.249281
#
#                capitalloss  hoursperweek    native    Salary
# age               0.057418      0.106105  0.018697  0.226220
# workclass         0.062026      0.077106  0.043338  0.077615
# education         0.038734      0.063598  0.069760  0.119016
# educationno       0.111713      0.145317  0.106144  0.313422
# maritalstatus    -0.018926     -0.161722  0.005488 -0.226209
# occupation       -0.038230      0.018785  0.004193  0.018910
# relationship     -0.037262     -0.298815  0.015321 -0.259728
# race              0.064287      0.058017  0.160356  0.076017
# sex               0.053486      0.233998 -0.037813  0.206553
# capitalgain      -0.036077      0.128418  0.032191  0.249281
# capitalloss       1.000000      0.062200  0.051320  0.163200
# hoursperweek      0.062200      1.000000 -0.026799  0.231284
# native            0.051320     -0.026799  1.000000  0.049529
# Salary            0.163200      0.231284  0.049529  1.000000

# %%
sns.pairplot(test)

# %%
X_train=train.iloc[:,:-1]
X_train
# Out:
#       age  workclass  education  educationno  maritalstatus  occupation  \
# 0      39          5          9           13              4           0
# 1      50          4          9           13              2           3
# 2      38          2         11            9              0           5
# 3      53          2          1            7              2           5
# 4      28          2          9           13              2           9
# ...   ...        ...        ...          ...            ...         ...
# 1995   33          2         11            9              5          10
# 1996   41          2         11            9              2           6
# 1997   51          2          6            5              2          13
# 1998   42          2         11            9              2          11
# 1999   27          2          9           13              2           9
#
#       relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0                1     4    1         2174            0            40      37
# 1                0     4    1            0            0            13      37
# 2                1     4    1            0            0            40      37
# 3                0     2    1            0            0            40      37
# 4                5     2    0            0            0            40       4
# ...            ...   ...  ...          ...          ...           ...     ...
# 1995             3     4    0            0            0            40      37
# 1996             0     4    1            0            0            40      37
# 1997             0     4    1            0            0            40      37
# 1998             0     4    1            0            0            48      37
# 1999             5     4    0            0            0            40      37
#
# [2000 rows x 13 columns]

# %%
X_test=test.iloc[:,:-1]
X_test
# Out:
#       age  workclass  education  educationno  maritalstatus  occupation  \
# 0      25          2          1            7              4           6
# 1      38          2         11            9              2           4
# 2      28          1          7           12              2          10
# 3      44          2         15           10              2           6
# 4      34          2          0            6              4           7
# ...   ...        ...        ...          ...            ...         ...
# 1295   66          4         15           10              2          13
# 1296   40          2         15           10              4           2
# 1297   37          2          4            3              2           6
# 1298   34          2          9           13              2          11
# 1299   41          4         12           14              6           9
#
#       relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# 0                3     2    1            0            0            40      37
# 1                0     4    1            0            0            50      37
# 2                0     4    1            0            0            40      37
# 3                0     2    1         7688            0            40      37
# 4                1     4    1            0            0            30      37
# ...            ...   ...  ...          ...          ...           ...     ...
# 1295             0     2    1            0            0            60      37
# 1296             2     0    1            0            0            30      37
# 1297             0     4    1            0            0            40       7
# 1298             0     4    1            0            0            40      37
# 1299             1     4    0            0            0            20      37
#
# [1300 rows x 13 columns]

# %%
y_train=train.iloc[:,-1]
y_train
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    1
# Name: Salary, Length: 2000, dtype: int32

# %%
y_test = test.iloc[:,-1]
y_test
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1295    0
# 1296    0
# 1297    0
# 1298    0
# 1299    0
# Name: Salary, Length: 1300, dtype: int32

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2000, 13), (2000,), (1300, 13), (1300,))

# %% [markdown]
# # SVM Model

# %%
model = SVC()

model.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ## Predicting model

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.99      0.88       966
#            1       0.93      0.20      0.33       334
#
#     accuracy                           0.79      1300
#    macro avg       0.86      0.60      0.60      1300
# weighted avg       0.82      0.79      0.74      1300

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[961   5]
#  [267  67]]

# %% [markdown]
# ## Improving Model using Grid Search CV

# %%
param_grid = {'C' : [1, 5, 10, 15, 20], 'gamma' : [1, 0.1, 0.01, 0.001, 0.0001], 'kernel' : ['rbf']}

# %%
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,  cv = 5)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.752 total time=   0.6s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.750 total time=   0.7s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.745 total time=   0.7s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.745 total time=   0.6s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.743 total time=   0.7s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.748 total time=   0.6s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.6s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.6s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.755 total time=   0.5s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.748 total time=   0.5s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.775 total time=   0.3s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.805 total time=   0.2s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.805 total time=   0.3s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.802 total time=   0.3s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.802 total time=   0.3s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.812 total time=   0.2s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.818 total time=   0.2s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.802 total time=   2.4s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.2s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 1/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.748 total time=   0.8s
# [CV 2/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.745 total time=   0.7s
# [CV 3/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.743 total time=   0.5s
# [CV 4/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.750 total time=   0.4s
# [CV 5/5] END ..........C=5, gamma=1, kernel=rbf;, score=0.750 total time=   0.7s
# [CV 1/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.728 total time=   0.5s
# [CV 2/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.730 total time=   0.5s
# [CV 3/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.730 total time=   0.6s
# [CV 4/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.5s
# [CV 5/5] END ........C=5, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.5s
# [CV 1/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.782 total time=   0.4s
# [CV 2/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.807 total time=   0.4s
# [CV 3/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.810 total time=   0.3s
# [CV 5/5] END .......C=5, gamma=0.01, kernel=rbf;, score=0.800 total time=   0.3s
# [CV 1/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.802 total time=   0.3s
# [CV 2/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 3/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 5/5] END ......C=5, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 1/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.2s
# [CV 2/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.2s
# [CV 3/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.812 total time=   0.2s
# [CV 4/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.818 total time=   0.2s
# [CV 5/5] END .....C=5, gamma=0.0001, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.748 total time=   0.7s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.745 total time=   0.7s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.743 total time=   0.6s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.750 total time=   0.6s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.750 total time=   0.6s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.728 total time=   0.6s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.5s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.728 total time=   0.5s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.745 total time=   0.7s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.733 total time=   0.6s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.787 total time=   0.5s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.792 total time=   0.4s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.790 total time=   0.3s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.818 total time=   0.3s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.4s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.823 total time=   0.4s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.825 total time=   0.4s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.2s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.2s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.3s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.818 total time=   0.4s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.812 total time=   0.2s
# [CV 1/5] END .........C=15, gamma=1, kernel=rbf;, score=0.748 total time=   0.7s
# [CV 2/5] END .........C=15, gamma=1, kernel=rbf;, score=0.745 total time=   0.7s
# [CV 3/5] END .........C=15, gamma=1, kernel=rbf;, score=0.743 total time=   0.7s
# [CV 4/5] END .........C=15, gamma=1, kernel=rbf;, score=0.750 total time=   0.5s
# [CV 5/5] END .........C=15, gamma=1, kernel=rbf;, score=0.750 total time=   0.7s
# [CV 1/5] END .......C=15, gamma=0.1, kernel=rbf;, score=0.720 total time=   0.6s
# [CV 2/5] END .......C=15, gamma=0.1, kernel=rbf;, score=0.730 total time=   0.4s
# [CV 3/5] END .......C=15, gamma=0.1, kernel=rbf;, score=0.725 total time=   0.2s
# [CV 4/5] END .......C=15, gamma=0.1, kernel=rbf;, score=0.745 total time=   0.2s
# [CV 5/5] END .......C=15, gamma=0.1, kernel=rbf;, score=0.735 total time=   0.3s
# [CV 1/5] END ......C=15, gamma=0.01, kernel=rbf;, score=0.777 total time=   0.1s
# [CV 2/5] END ......C=15, gamma=0.01, kernel=rbf;, score=0.818 total time=   0.2s
# [CV 3/5] END ......C=15, gamma=0.01, kernel=rbf;, score=0.792 total time=   0.3s
# [CV 4/5] END ......C=15, gamma=0.01, kernel=rbf;, score=0.800 total time=   0.3s
# [CV 5/5] END ......C=15, gamma=0.01, kernel=rbf;, score=0.792 total time=   0.3s
# [CV 1/5] END .....C=15, gamma=0.001, kernel=rbf;, score=0.818 total time=   0.2s
# [CV 2/5] END .....C=15, gamma=0.001, kernel=rbf;, score=0.820 total time=   0.2s
# [CV 3/5] END .....C=15, gamma=0.001, kernel=rbf;, score=0.825 total time=   0.2s
# [CV 4/5] END .....C=15, gamma=0.001, kernel=rbf;, score=0.812 total time=   0.3s
# [CV 5/5] END .....C=15, gamma=0.001, kernel=rbf;, score=0.825 total time=   0.2s
# [CV 1/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.2s
# [CV 2/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.3s
# [CV 3/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 4/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 5/5] END ....C=15, gamma=0.0001, kernel=rbf;, score=0.812 total time=   0.2s
# [CV 1/5] END .........C=20, gamma=1, kernel=rbf;, score=0.748 total time=   0.6s
# [CV 2/5] END .........C=20, gamma=1, kernel=rbf;, score=0.745 total time=   0.6s
# [CV 3/5] END .........C=20, gamma=1, kernel=rbf;, score=0.743 total time=   0.5s
# [CV 4/5] END .........C=20, gamma=1, kernel=rbf;, score=0.750 total time=   0.6s
# [CV 5/5] END .........C=20, gamma=1, kernel=rbf;, score=0.750 total time=   0.6s
# [CV 1/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.723 total time=   0.5s
# [CV 2/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.730 total time=   0.5s
# [CV 3/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.725 total time=   0.4s
# [CV 4/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.745 total time=   0.4s
# [CV 5/5] END .......C=20, gamma=0.1, kernel=rbf;, score=0.738 total time=   0.4s
# [CV 1/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.767 total time=   0.3s
# [CV 2/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.807 total time=   0.3s
# [CV 3/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.787 total time=   0.3s
# [CV 4/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.802 total time=   0.3s
# [CV 5/5] END ......C=20, gamma=0.01, kernel=rbf;, score=0.785 total time=   0.3s
# [CV 1/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 2/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.818 total time=   0.2s
# [CV 3/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.825 total time=   0.1s
# [CV 4/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.810 total time=   0.1s
# [CV 5/5] END .....C=20, gamma=0.001, kernel=rbf;, score=0.823 total time=   0.2s
# [CV 1/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.2s
# [CV 2/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.807 total time=   0.2s
# [CV 3/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.2s
# [CV 4/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.818 total time=   0.2s
# [CV 5/5] END ....C=20, gamma=0.0001, kernel=rbf;, score=0.815 total time=   0.2s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 15, 20],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 15, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
grid_pred = grid.predict(X_test)

# %%
grid_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(confusion_matrix(y_test, grid_pred))
# Out:
# [[938  28]
#  [198 136]]

# %%
print(classification_report(y_test, grid_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89       966
#            1       0.83      0.41      0.55       334
#
#     accuracy                           0.83      1300
#    macro avg       0.83      0.69      0.72      1300
# weighted avg       0.83      0.83      0.80      1300

# %% [markdown]
# ### Inference, So, using grid search method, we improved our model accuracy from 0.79 to 0.83
