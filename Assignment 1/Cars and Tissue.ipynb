# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cars_data = pd.read_csv('cars.csv')
wc_ac = pd.read_csv('wc-at.csv')

# %%
cars_data.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars_data[cars_data['MPG'] >  38].count()['MPG']/len(cars_data)
# Out:
# 0.4074074074074074

# %%
cars_data[cars_data['MPG'] < 40].count()['MPG']/len(cars_data)
# Out:
# 0.7530864197530864

# %%
cars_data[(cars_data['MPG'] >  20) & (cars_data['MPG'] < 50)].count()['MPG']/len(cars_data)
# Out:
# 0.8518518518518519

# %%
plt.boxplot(cars_data['MPG'])
plt.show()

# %%
cars_data['MPG'].skew()
# Out:
# -0.17794674747025727

# %%
wc_ac.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
plt.boxplot(wc_ac)
plt.show()

# %%
wc_ac.skew()
# Out:
# Waist    0.134056
# AT       0.584869
# dtype: float64
